# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriellemga/Python_Cursos_Alura/blob/main/Pandas_selecionando_agrupando_dados/Desafio_agrupando_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio 01: hora da prática

# %% [markdown]
# A base de dados a ser utilizada está disponível no site do SEEG - Sistema de Estimativa de Emissões e Remoções de Gases de Efeito Estufa, basta clicar em “Plataforma de dados”  ou no link [dados](https://cdn3.gnarususercontent.com.br/2927-pandas-selecao-agrupamento-dados/1-SEEG10_GERAL-BR_UF_2022.10.27-FINAL-SITE.xlsx).

# %% [markdown]
#  Solucione os problemas propostos através de códigos utilizando a base de dados disponibilizada no curso.

# %%
import pandas as pd

# %%
url= '/content/sample_data/1-SEEG10_GERAL-BR_UF_2022.10.27-FINAL-SITE.xlsx'

# %%
emissoes_estado = pd.read_excel(url, sheet_name = 'GEE Estados')
emissoes_estado
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                            Nível 1 - Setor  \
# 0                    Processos Industriais
# 1                    Processos Industriais
# 2                    Processos Industriais
# 3                    Processos Industriais
# 4                    Processos Industriais
# ...                                    ...
# 103307  Mudança de Uso da Terra e Floresta
# 103308  Mudança de Uso da Terra e Floresta
# 103309  Mudança de Uso da Terra e Floresta
# 103310  Mudança de Uso da Terra e Floresta
# 103311  Mudança de Uso da Terra e Floresta
#
#                                         Nível 2                    Nível 3  \
# 0                             Indústria Química            Produção de ABS
# 1                             Indústria Química  Produção de Ácido Adípico
# ...

# %% [markdown]
# 1-Encontre os valores únicos das colunas "Nível 1 - Setor" e "Estado" para identificar as atividades econômicas presentes na base de dados e se todos os Estados do Brasil estão presentes no DataFrame.

# %%
emissoes_estado['Nível 1 - Setor'].unique(), emissoes_estado['Estado'].unique()
# Out:
# (array(['Processos Industriais', 'Agropecuária', 'Energia', 'Resíduos ',
#         'Mudança de Uso da Terra e Floresta'], dtype=object),
#  array(['SP', 'BA', 'RJ', 'MG', 'SE', 'PR', nan, 'RO', 'AM', 'PA', 'TO',
#         'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'MT', 'MS', 'GO', 'DF',
#         'ES', 'SC', 'RS', 'AC', 'AP', 'RR', 'BR'], dtype=object))

# %% [markdown]
# 2- Filtre o DataFrame somente com os dados dos Estados da região Sul do Brasil.

# %%
emissoes_regiaosul = emissoes_estado[emissoes_estado['Estado'].isin(['RS', 'PR', 'SC'])]
emissoes_regiaosul
# Out:
#                            Nível 1 - Setor              Nível 2  \
# 35                   Processos Industriais    Indústria Química
# 36                   Processos Industriais    Indústria Química
# 37                   Processos Industriais    Indústria Química
# 110                  Processos Industriais    Produtos Minerais
# 111                  Processos Industriais    Produtos Minerais
# ...                                    ...                  ...
# 103221  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103222  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103223  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103224  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103225  Mudança de Uso da Terra e Floresta  Resíduos Florestais
#
#                     Nível 3 Nível 4       Nível 5 Nível 6  \
# 35       Produção de Amônia     NaN           NaN     NaN
# 36       Produção de Amônia     NaN           NaN     NaN
# ...

# %% [markdown]
# 3-Filtre o DataFrame para exibir apenas os registros em que o campo "Nível 1 - Setor" seja igual a "Mudança de Uso da Terra e Floresta" e o campo "Estado" seja igual a "AM" (sigla para o Estado do Amazonas).

# %%
emissao_mut_am = emissoes_estado[(emissoes_estado['Nível 1 - Setor'] == 'Mudança de Uso da Terra e Floresta') & (emissoes_estado['Estado'] == 'AM')]
emissao_mut_am
# Out:
#                            Nível 1 - Setor                     Nível 2  \
# 81262   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81271   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81280   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81289   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81298   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# ...                                    ...                         ...
# 102803  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102812  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102821  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102830  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102839  Mudança de Uso da Terra e Floresta         Resíduos Florestais
#
#          Nível 3                 Nível 4       Nível 5  \
# 81262   Amazônia  fora de Área Protegida  Desmatamento
# ...

# %% [markdown]
# 4-Encontre o valor máximo de emissão do ano de 2021 para os dados de "Agropecuária" no Estado do Pará.

# %%
emissao_agro_pa = emissoes_estado.loc[(emissoes_estado['Nível 1 - Setor'] == 'Agropecuária') & (emissoes_estado['Estado'] == 'PA'), 2021]
emissao_agro_pa.max()
# Out:
# 36856969.7986

# %% [markdown]
# # Desafio 02: hora da prática

# %% [markdown]
#  Solucione os problemas propostos através de códigos utilizando a base de dados disponibilizada no curso.

# %% [markdown]
# 1-Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" para visualizar o dicionário contendo as chaves de grupos formados e a lista de índices de cada grupo.

# %%
colunas_info = list(emissoes_estado.loc[:, 'Nível 1 - Setor':'Produto'].columns)
colunas_emissao = list(emissoes_estado.loc[:, 1970:2021].columns)
emissoes_por_ano = emissoes_estado.melt(id_vars = colunas_info, value_vars = colunas_emissao, var_name = 'Ano' , value_name = 'Emissão')

# %%
emissoes_por_ano.groupby('Nível 1 - Setor').groups
# Out:
# {'Agropecuária': [1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, ...], 'Energia': [24735, 24736, 24737, 24738, 24739, 24740, 24741, 24742, 24743, 24744, 24745, 24746, 24747, 24748, 24749, 24750, 24751, 24752, 24753, 24754, 24755, 24756, 24757, 24758, 24759, 24760, 24761, 24762, 24763, 24764, 24765, 24766, 24767, 24768, 24769, 24770, 24771, 24772, 24773, 24774, 24775, 24776, 24777, 24778, 24779, 24780, 24781, 24782, 24783, 24784, 24785, 24786
# ...

# %% [markdown]
# 2-Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" e localize os dados do grupo "Agropecuária".

# %%
emissoes_por_ano.groupby('Nível 1 - Setor').get_group('Agropecuária')
# Out:
#         Nível 1 - Setor           Nível 2  Nível 3  \
# 1137       Agropecuária  Cultivo de Arroz  Diretas
# 1138       Agropecuária  Cultivo de Arroz  Diretas
# 1139       Agropecuária  Cultivo de Arroz  Diretas
# 1140       Agropecuária  Cultivo de Arroz  Diretas
# 1141       Agropecuária  Cultivo de Arroz  Diretas
# ...                 ...               ...      ...
# 5293642    Agropecuária   Solos Manejados  Diretas
# 5293643    Agropecuária   Solos Manejados  Diretas
# 5293644    Agropecuária   Solos Manejados  Diretas
# 5293645    Agropecuária   Solos Manejados  Diretas
# 5293646    Agropecuária   Solos Manejados  Diretas
#
#                                           Nível 4  Nível 5  \
# 1137                                       Outros  Vegetal
# 1138                                       Outros  Vegetal
# 1139                                       Outros  Vegetal
# 1140                                       Outros  Vegetal
# ...

# %% [markdown]
# 3-Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" para identificar a média de emissão de cada setor no ano de 2021.

# %%
emissoes_por_ano.groupby('Nível 1 - Setor')[['Emissão']].mean()
# Out:
#                                           Emissão
# Nível 1 - Setor
# Agropecuária                         90236.332221
# Energia                              45393.293635
# Mudança de Uso da Terra e Floresta  217533.303924
# Processos Industriais               482031.877565
# Resíduos                             52131.972855

# %% [markdown]
# 4-Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" para identificar a soma de emissão de cada setor. Ordene os dados da maior para menor emissão.

# %%
emissoes_por_ano.groupby('Nível 1 - Setor')[['Emissão']].sum().sort_values('Emissão', ascending = False)
# Out:
#                                          Emissão
# Nível 1 - Setor
# Mudança de Uso da Terra e Floresta  2.494463e+11
# Energia                             1.244170e+11
# Agropecuária                        1.107286e+11
# Processos Industriais               2.849965e+10
# Resíduos                            1.034465e+10

# %% [markdown]
# # Desafio: emissão por setor econômico

# %% [markdown]
# A equipe de supervisão deseja saber agora a média de emissão para cada um dos setores econômicos da coluna "Nível 1 - Setor" ao longo dos anos. Como desafio, crie uma tabela de pivô e uma visualização gráfica contendo essas informações, utilizando apenas o método pivot_table para a construção da tabela, sem utilizar o método groupby.

# %%
emissao_anual_setor1 = emissoes_por_ano[['Nível 1 - Setor', 'Ano','Emissão']]

media_emissao_anual_setor1 = emissao_anual_setor1.pivot_table(index = 'Ano', columns = 'Nível 1 - Setor', values = 'Emissão', aggfunc = 'mean')
media_emissao_anual_setor1

media_emissao_anual_setor1.plot(subplots = True, figsize = (10,20));

# %% [markdown]
# # Desafio 03: hora da prática

# %% [markdown]
# Solucione os problemas propostos através de códigos utilizando a base de dados disponibilizada no curso.
#
# 1- Faça um agrupamento de dados com as colunas "Estado" e "Nível 1 - Setor", obtendo a soma de emissão e armazenando o resultado em uma tabela.

# %%
emissao_estado_nivel1 = emissoes_por_ano.groupby(['Estado', 'Nível 1 - Setor'])[['Emissão']].sum()
emissao_estado_nivel1
# Out:
#                                                 Emissão
# Estado Nível 1 - Setor
# AC     Agropecuária                       -3.272006e+08
#        Energia                             2.071751e+08
#        Mudança de Uso da Terra e Floresta  4.704492e+09
#        Resíduos                            2.928323e+07
# AL     Agropecuária                        1.215829e+09
# ...                                                 ...
# TO     Agropecuária                        2.789108e+09
#        Energia                             5.130379e+08
#        Mudança de Uso da Terra e Floresta  6.486598e+09
#        Processos Industriais               2.613905e+07
#        Resíduos                            6.177003e+07
#
# [133 rows x 1 columns]

# %% [markdown]
# 2- Utilizando a tabela construída na atividade 1, selecione os dados referentes à "Energia" do índice "Nível 1 - Setor".

# %%
emissao_estado_nivel1.xs('Energia', level = 1)
# Out:
#              Emissão
# Estado
# AC      2.071751e+08
# AL      5.958697e+08
# AM      1.916462e+09
# AP      2.638059e+08
# BA      4.801368e+09
# CE      1.879584e+09
# DF      9.487860e+08
# ES      2.201326e+09
# GO      2.761709e+09
# MA      1.699005e+09
# MG      9.663844e+09
# MS      1.593967e+09
# MT      2.296983e+09
# PA      2.730706e+09
# PB      8.358578e+08
# PE      2.089593e+09
# PI      5.044902e+08
# PR      5.502734e+09
# RJ      9.151787e+09
# RN      9.473144e+08
# RO      7.246552e+08
# RR      1.672719e+08
# RS      5.901596e+09
# SC      4.328366e+09
# SE      6.627356e+08
# SP      2.214979e+10
# TO      5.130379e+08

# %% [markdown]
# 3 - Utilizando a tabela construída na atividade 1, encontre a atividade econômica com valor máximo de emissão do Estado de Minas Gerais

# %%
emissao_estado_nivel1.xs('MG', level = 0).idxmax()
# Out:
# Emissão    Agropecuária
# dtype: object

# %% [markdown]
# 4- Obtenha uma tabela contendo a atividade econômica com máxima emissão para cada Estado.

# %%
emissao_estado_nivel1 = emissoes_por_ano.groupby(['Estado', 'Nível 1 - Setor'])[['Emissão']].sum()
emissao_estado_nivel1.groupby(level = 0 ).idxmax()
# Out:
#                                          Emissão
# Estado
# AC      (AC, Mudança de Uso da Terra e Floresta)
# AL                            (AL, Agropecuária)
# AM                                 (AM, Energia)
# AP                                 (AP, Energia)
# BA                            (BA, Agropecuária)
# BR      (BR, Mudança de Uso da Terra e Floresta)
# CE                            (CE, Agropecuária)
# DF                                 (DF, Energia)
# ES                   (ES, Processos Industriais)
# GO                            (GO, Agropecuária)
# MA      (MA, Mudança de Uso da Terra e Floresta)
# MG                            (MG, Agropecuária)
# MS                            (MS, Agropecuária)
# MT      (MT, Mudança de Uso da Terra e Floresta)
# PA      (PA, Mudança de Uso da Terra e Floresta)
# PB                            (PB, Agropecuária)
# PE                            (PE, Agropecuária)
# PI                            (PI, Agropecuária)
# ...

# %% [markdown]
# 5- Obtenha uma tabela contendo o Estado com máxima emissão para cada atividade econômica.

# %%
emissao_estado_nivel1 = emissoes_por_ano.groupby(['Estado', 'Nível 1 - Setor'])[['Emissão']].sum()
emissao_estado_nivel1.groupby(level = 1 ).idxmax()
# Out:
#                                                                      Emissão
# Nível 1 - Setor
# Agropecuária                                              (MG, Agropecuária)
# Energia                                                        (SP, Energia)
# Mudança de Uso da Terra e Floresta  (MT, Mudança de Uso da Terra e Floresta)
# Processos Industriais                            (MG, Processos Industriais)
# Resíduos                                                     (SP, Resíduos )
